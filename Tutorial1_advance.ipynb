# %% [markdown]
# ## Tutorial 1 advance: The inputs and outputs of ZigZag
# This tutorial shows you how to define workload with more layers with residual/branch connection in ZigZag format.

# %%
workload = {
    0: {  # conv1, stride 2
        'operator_type': 'Conv',
        'equation': 'O[b][k][oy][ox]+=W[k][c][fy][fx]*I[b][c][iy][ix]',
        'dimension_relations': ['ix=2*ox+1*fx', 'iy=2*oy+1*fy'],
        'loop_dim_size': {'B': 1, 'K': 64, 'C': 3, 'OY': 112, 'OX': 112, 'FY': 7, 'FX': 7},
        'operand_precision': {'O': 16, 'O_final': 8, 'W': 8, 'I': 8},
        'operand_source': {'W': [], 'I': []},
        'constant_operands': ['I', 'W'],
    }
    ,
    1: {  # max pool, stride 2
        'operator_type': 'Pooling',
        'equation': 'O[b][g][oy][ox]+=W[fx][fy]*I[b][g][iy][ix]',
        'dimension_relations': ['ix=2*ox+1*fx', 'iy=2*oy+1*fy'],
        'loop_dim_size': {'B': 1, 'G': 64, 'OY': 56, 'OX': 56, 'FX': 3, 'FY': 3},
        'operand_precision': {'O': 16, 'O_final': 8, 'I': 8, 'W': 0},
        'operand_source': {'W': [], 'I': [0]},
        'constant_operands': ['W'],
        'operand_source_dimension_mapping': {'I': {'IX': 'OX', 'IY': 'OY', 'G': 'K'}},
    }
    ,
    2: {  # conv2_1
        'operator_type': 'Conv',
        'equation': 'O[b][k][oy][ox]+=W[k][c][fy][fx]*I[b][c][iy][ix]',
        'dimension_relations': ['ix=1*ox+1*fx', 'iy=1*oy+1*fy'],
        'loop_dim_size': {'B': 1, 'K': 64, 'C': 64, 'OY': 56, 'OX': 56, 'FY': 3, 'FX': 3, },
        'operand_precision': {'O': 16, 'O_final': 8, 'W': 8, 'I': 8},
        'operand_source': {'W': [], 'I': [1]},
        'constant_operands': ['W'],
        'operand_source_dimension_mapping': {'I': {'IX': 'OX', 'IY': 'OY', 'C': 'G'}},
    }
    ,
    3: {  # conv2_2
        'operator_type': 'Conv',
        'equation': 'O[b][k][oy][ox]+=W[k][c][fy][fx]*I[b][c][iy][ix]',
        'dimension_relations': ['ix=1*ox+1*fx', 'iy=1*oy+1*fy'],
        'loop_dim_size': {'B': 1, 'K': 64, 'C': 64, 'OY': 56, 'OX': 56, 'FY': 3, 'FX': 3, },
        'operand_precision': {'O': 16, 'O_final': 8, 'W': 8, 'I': 8},
        'operand_source': {'W': [], 'I': [2]},
        'constant_operands': ['W'],
        'operand_source_dimension_mapping': {'I': {'IX': 'OX', 'IY': 'OY', 'C': 'K'}},
    }
    ,
    4: {  # Addition of layer 1 (residual path) and layer 3 (main path)
        'operator_type': 'Add',
        'equation': 'O[b][g][oy][ox]=X[b][g][oy][ox]+Y[b][g][oy][ox]',
        'dimension_relations': [],
        'loop_dim_size': {'B': 1, 'G': 64, 'OY': 56, 'OX': 56},
        'operand_precision': {'O': 16, 'O_final': 8, 'X': 8, 'Y': 8},
        'operand_source': {'X': [1], 'Y': [3]},
        'constant_operands': [],
        'operand_source_dimension_mapping': {'X': {'OX': 'OX', 'OY': 'OY', 'G': 'K'}, 'Y': {'OX': 'OX', 'OY': 'OY', 'G': 'K'}},
    }
}

# %% [markdown]
# Define the mapping info for each operator_type

# %%
mapping = {
    "Conv": {
        "core_allocation": 1,
        "spatial_mapping": {'D1': ('K', 32), 'D2': ('C', 32)},
        "memory_operand_links": {'O': 'O', 'W': 'I2', 'I': 'I1'}
    },
    "Pooling": {
        "core_allocation": 1,
        "spatial_mapping": {'D1': ('G', 32)},
        "memory_operand_links": {'O': 'O', 'W': 'I2', 'I': 'I1'}
    },
    "Add": {
        "core_allocation": 1,
        "spatial_mapping": {'D1': ('G', 32)},
        "memory_operand_links": {'O': 'O', 'X': 'I2', 'Y': 'I1'}
    }
}

# %% [markdown]
# Define our own HW architecture

# %%
from zigzag.classes.hardware.architecture.memory_hierarchy import MemoryHierarchy
from zigzag.classes.hardware.architecture.operational_unit import Multiplier
from zigzag.classes.hardware.architecture.operational_array import MultiplierArray
from zigzag.classes.hardware.architecture.memory_instance import MemoryInstance
from zigzag.classes.hardware.architecture.accelerator import Accelerator
from zigzag.classes.hardware.architecture.core import Core

def memory_hierarchy_dut(multiplier_array):
    """Memory hierarchy variables"""
    ''' size=#bit, bw=(read bw, write bw), cost=(read word energy, write work energy) '''

    reg_2B = MemoryInstance(name="rf_2B", size=16, r_bw=16, w_bw=16, r_cost=0.021, w_cost=0.021, area=0,
                              r_port=2, w_port=2, rw_port=0, latency=1)

    reg_32B = MemoryInstance(name="rf_32B", size=32 * 8, r_bw=8, w_bw=8, r_cost=0.055, w_cost=0.055, area=0,
                            r_port=1, w_port=1, rw_port=0, latency=1)

    reg_128B = MemoryInstance(name="rf_128B", size=128 * 8, r_bw=8, w_bw=8, r_cost=0.095, w_cost=0.095, area=0,
                                r_port=1, w_port=1, rw_port=0, latency=1)

    sram_2M_with_16_128K_bank_128_1r_1w = \
        MemoryInstance(name="sram_2MB", size=131072 * 16 * 8, r_bw=128 * 16, w_bw=128 * 16, r_cost=26.01 * 16, w_cost=23.65 * 16, area=0,
                       r_port=1, w_port=1, rw_port=0, latency=1, min_r_granularity=64, min_w_granularity=64)

    dram = MemoryInstance(name="dram", size=10000000000, r_bw=64, w_bw=64, r_cost=500, w_cost=550, area=0,
                          r_port=0, w_port=0, rw_port=1, latency=1)

    memory_hierarchy_graph = MemoryHierarchy(operational_array=multiplier_array)

    '''
    fh: from high = wr_in_by_high
    fl: from low = wr_in_by_low
    th: to high = rd_out_to_high
    tl: to low = rd_out_to_low
    '''
    memory_hierarchy_graph.add_memory(memory_instance=reg_32B, operands=('I1',),
                                      port_alloc=({'fh': 'w_port_1', 'tl': 'r_port_1', 'fl': None, 'th': None},),
                                      served_dimensions={(1, 0)})

    memory_hierarchy_graph.add_memory(memory_instance=reg_2B, operands=('O',),
                                      port_alloc=({'fh': 'w_port_1', 'tl': 'r_port_1', 'fl': 'w_port_2', 'th': 'r_port_2'},),
                                      served_dimensions={(0, 1)})

    memory_hierarchy_graph.add_memory(memory_instance=reg_128B, operands=('I2',),
                                      port_alloc=({'fh': 'w_port_1', 'tl': 'r_port_1', 'fl': None, 'th': None},),
                                      served_dimensions={(0, 0)})

    memory_hierarchy_graph.add_memory(memory_instance=sram_2M_with_16_128K_bank_128_1r_1w, operands=('I1', 'O'),
                                      port_alloc=({'fh': 'w_port_1', 'tl': 'r_port_1', 'fl': None, 'th': None},
                                                  {'fh': 'w_port_1', 'tl': 'r_port_1', 'fl': 'w_port_1', 'th': 'r_port_1'},),
                                      served_dimensions='all')

    memory_hierarchy_graph.add_memory(memory_instance=dram, operands=('I1', 'I2', 'O'),
                                      port_alloc=({'fh': 'rw_port_1', 'tl': 'rw_port_1', 'fl': None, 'th': None},
                                                  {'fh': 'rw_port_1', 'tl': 'rw_port_1', 'fl': None, 'th': None},
                                                  {'fh': 'rw_port_1', 'tl': 'rw_port_1', 'fl': 'rw_port_1', 'th': 'rw_port_1'},),
                                      served_dimensions='all')

    from zigzag.visualization.graph.memory_hierarchy import visualize_memory_hierarchy_graph
    visualize_memory_hierarchy_graph(memory_hierarchy_graph)
    return memory_hierarchy_graph


def multiplier_array_dut():
    """ Multiplier array variables """
    multiplier_input_precision = [8, 8]
    multiplier_energy = 0.04
    multiplier_area = 1
    dimensions = {'D1': 32, 'D2': 32}  # {'D1': ('K', 32), 'D2': ('C', 32)}

    multiplier = Multiplier(multiplier_input_precision, multiplier_energy, multiplier_area)
    multiplier_array = MultiplierArray(multiplier, dimensions)

    return multiplier_array


def cores():
    multiplier_array1 = multiplier_array_dut()
    memory_hierarchy1 = memory_hierarchy_dut(multiplier_array1)
    core1 = Core(1, multiplier_array1, memory_hierarchy1)
    return {core1}


cores = cores()
global_buffer = None
acc_name = 'our_own_accelerator'
accelerator = Accelerator(acc_name, cores, global_buffer)

# %% [markdown]
# Now, we have everything we need, let's set the output filenames and call ZigZag API function

# %%
# Set the filenames
dump_filename_pattern=f"outputs/Our_HW-multi_layer_?.json"
pickle_filename = f"outputs/Our_HW-multi_layer_cme.pickle"

# %%
# call ZigZag API function
from zigzag.api import get_hardware_performance_zigzag

energy, latency, cme = get_hardware_performance_zigzag(workload=workload,
                                                       accelerator=accelerator,
                                                       mapping=mapping,
                                                       opt='energy',
                                                       dump_filename_pattern=dump_filename_pattern,
                                                       pickle_filename=pickle_filename)
# Out:
# 2023-02-09 12:57:41,068 - parse_workload_from_path_or_from_module +41 - INFO - Created workload graph with 5 nodes and 5 edges.
# 2023-02-09 12:57:41,069 - run +33 - INFO - Processing layer 0...
# 2023-02-09 12:57:41,070 - run +81 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2023-02-09 12:57:41,071 - run +82 - INFO - Running temporal mapping search engine...
# 100%|██████████| 720/720 [00:01<00:00, 405.33it/s]
# 2023-02-09 12:57:42,857 - run +44 - INFO - Saved CostModelEvaluation(layer=LayerNode_0, core=1) with energy 1.023e+08 and latency 1.349e+06 to outputs/Our_HW-multi_layer_LayerNode_0_completeSave.json
# 2023-02-09 12:57:42,857 - run +33 - INFO - Processing layer 1...
# 2023-02-09 12:57:42,857 - run +81 - INFO - Launching spatial mapping 1/1: {'D1': ('G', 32)}.
# 2023-02-09 12:57:42,858 - run +82 - INFO - Running temporal mapping search engine...
# 100%|██████████| 720/720 [00:01<00:00, 478.21it/s]
# 2023-02-09 12:57:44,369 - run +44 - INFO - Saved CostModelEvaluation(layer=LayerNode_1, core=1) with energy 9.055e+07 and latency 1.934e+06 to outputs/Our_HW-multi_layer_LayerNode_1_completeSave.json
# 2023-02-09 12:57:44,371 - run +33 - INFO - Processing layer 2...
# 2023-02-09 12:57:44,371 - run +81 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2023-02-09 12:57:44,372 - run +82 - INFO - Running temporal mapping search engine...
# 100%|██████████| 720/720 [00:01<00:00, 454.80it/s]
# 2023-02-09 12:57:45,962 - run +44 - INFO - Saved CostModelEvaluation(layer=LayerNode_2, core=1) with energy 4.950e+07 and latency 1.649e+05 to outputs/Our_HW-multi_layer_LayerNode_2_completeSave.json
# 2023-02-09 12:57:45,963 - run +33 - INFO - Processing layer 3...
# 2023-02-09 12:57:45,964 - run +81 - INFO - Launching spatial mapping 1/1: {'D1': ('K', 32), 'D2': ('C', 32)}.
# 2023-02-09 12:57:45,964 - run +82 - INFO - Running temporal mapping search engine...
# 100%|██████████| 720/720 [00:01<00:00, 399.12it/s]
# 2023-02-09 12:57:47,774 - run +44 - INFO - Saved CostModelEvaluation(layer=LayerNode_3, core=1) with energy 4.950e+07 and latency 1.649e+05 to outputs/Our_HW-multi_layer_LayerNode_3_completeSave.json
# 2023-02-09 12:57:47,778 - run +33 - INFO - Processing layer 4...
# 2023-02-09 12:57:47,781 - run +81 - INFO - Launching spatial mapping 1/1: {'D1': ('G', 32)}.
# 2023-02-09 12:57:47,782 - run +82 - INFO - Running temporal mapping search engine...
# 100%|██████████| 720/720 [00:01<00:00, 433.57it/s]
# 2023-02-09 12:57:49,448 - run +44 - INFO - Saved CostModelEvaluation(layer=LayerNode_4, core=1) with energy 4.249e+07 and latency 2.509e+05 to outputs/Our_HW-multi_layer_LayerNode_4_completeSave.json
# 2023-02-09 12:57:49,451 - run +97 - INFO - Saved CostModelEvaluation(layer=[0, 1, 2, 3, 4], core=[1, 1, 1, 1, 1]) with energy 3.344e+08 and latency 3.864e+06 to outputs/Our_HW-multi_layer_overall_simpleSave.json
# 2023-02-09 12:57:49,457 - run +149 - INFO - Saved pickled list of 5 CMEs to outputs/Our_HW-multi_layer_cme.pickle.

# %%
print(f"Total network energy = {energy:.2e} pJ")
print(f"Total network latency = {latency:.2e} cycles")
# Out:
# Total network energy = 3.34e+08 pJ
# Total network latency = 3.86e+06 cycles

# %% [markdown]
# Let's have a look of the energy/latency breakdown.

# %%
import pickle
from zigzag.visualization.results.plot_cme import bar_plot_cost_model_evaluations_breakdown

# Load in the pickled CME
with open(pickle_filename, 'rb') as fp:
    cme_for_the_multi_layer = pickle.load(fp)

bar_plot_cost_model_evaluations_breakdown(cme_for_the_multi_layer, save_path="plot_multi_layer_breakdown.png")

# %% [markdown]
# Let's have a look of the best temporal mapping found.

# %%
from zigzag.visualization.results.print_mapping import print_mapping
from zigzag.visualization.graph.memory_hierarchy import visualize_memory_hierarchy_graph

visualize_memory_hierarchy_graph(cme_for_the_multi_layer[0].accelerator.cores[0].memory_hierarchy)
for cme in cme_for_the_multi_layer:
    print_mapping(cme)
# Out:
#
# ******* Temporal Mapping - CostModelEvaluation(layer=LayerNode_0, core=1) *******
#  O (O): [[('FX', 7), ('FY', 7)], [('OY', 112), ('OX', 16), ('OX', 7), ('K', 2)], []]
#  W (I2): [[('FX', 7), ('FY', 7), ('OY', 112), ('OX', 16), ('OX', 7), ('K', 2)], []]
#  I (I1): [[('FX', 7)], [('FY', 7), ('OY', 112), ('OX', 16), ('OX', 7), ('K', 2)], []]
#
# ---------------------------------------------------------------------------------
#  Temporal Loops                 O                 W                 I
# ---------------------------------------------------------------------------------
#  for K in [0:2)                 sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#   for OX in [0:7)               sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#    for OX in [0:16)             sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#     for OY in [0:112)           sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#      for FY in [0:7)            rf_2B             rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#       for FX in [0:7)           rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#
#
#
# ******* Temporal Mapping - CostModelEvaluation(layer=LayerNode_1, core=1) *******
#  O (O): [[('FX', 3), ('FY', 3)], [('OY', 56), ('OX', 8), ('OX', 7), ('G', 2)], []]
#  W (I2): [[('FX', 3), ('FY', 3), ('OY', 56), ('OX', 8), ('OX', 7), ('G', 2)], []]
#  I (I1): [[], [('FX', 3), ('FY', 3), ('OY', 56), ('OX', 8), ('OX', 7), ('G', 2)], []]
#
# ---------------------------------------------------------------------------------
#  Temporal Loops                 O                 W                 I
# ---------------------------------------------------------------------------------
#  for G in [0:2)                 sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#   for OX in [0:7)               sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#    for OX in [0:8)              sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#     for OY in [0:56)            sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#      for FY in [0:3)            rf_2B             rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#       for FX in [0:3)           rf_2B             rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#
#
#
# ******* Temporal Mapping - CostModelEvaluation(layer=LayerNode_2, core=1) *******
#  O (O): [[('C', 2), ('FY', 3), ('FX', 3)], [('K', 2), ('OY', 56), ('OX', 56)], []]
#  W (I2): [[('C', 2), ('FY', 3), ('FX', 3), ('K', 2), ('OY', 56), ('OX', 56)], []]
#  I (I1): [[('C', 2), ('FY', 3), ('FX', 3), ('K', 2)], [('OY', 56), ('OX', 56)], []]
#
# ---------------------------------------------------------------------------------
#  Temporal Loops                 O                 W                 I
# ---------------------------------------------------------------------------------
#  for OX in [0:56)               sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#   for OY in [0:56)              sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#    for K in [0:2)               sram_2MB          rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#     for FX in [0:3)             rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#      for FY in [0:3)            rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#       for C in [0:2)            rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#
#
#
# ******* Temporal Mapping - CostModelEvaluation(layer=LayerNode_3, core=1) *******
#  O (O): [[('C', 2), ('FY', 3), ('FX', 3)], [('K', 2), ('OY', 56), ('OX', 56)], []]
#  W (I2): [[('C', 2), ('FY', 3), ('FX', 3), ('K', 2), ('OY', 56), ('OX', 56)], []]
#  I (I1): [[('C', 2), ('FY', 3), ('FX', 3), ('K', 2)], [('OY', 56), ('OX', 56)], []]
#
# ---------------------------------------------------------------------------------
#  Temporal Loops                 O                 W                 I
# ---------------------------------------------------------------------------------
#  for OX in [0:56)               sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#   for OY in [0:56)              sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#    for K in [0:2)               sram_2MB          rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#     for FX in [0:3)             rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#      for FY in [0:3)            rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#       for C in [0:2)            rf_2B             rf_128B           rf_32B
# ---------------------------------------------------------------------------------
#
#
#
# ******* Temporal Mapping - CostModelEvaluation(layer=LayerNode_4, core=1) *******
#  O (O): [[('G', 2)], [('OY', 8), ('OY', 7), ('OX', 7), ('OX', 4), ('OX', 2)], []]
#  X (I2): [[('G', 2), ('OY', 8), ('OY', 7)], [('OX', 7), ('OX', 4), ('OX', 2)]]
#  Y (I1): [[], [('G', 2), ('OY', 8), ('OY', 7), ('OX', 7), ('OX', 4), ('OX', 2)], []]
#
# ---------------------------------------------------------------------------------
#  Temporal Loops                 O                 X                 Y
# ---------------------------------------------------------------------------------
#  for OX in [0:2)                sram_2MB          dram              sram_2MB
# ---------------------------------------------------------------------------------
#   for OX in [0:4)               sram_2MB          dram              sram_2MB
# ---------------------------------------------------------------------------------
#    for OX in [0:7)              sram_2MB          dram              sram_2MB
# ---------------------------------------------------------------------------------
#     for OY in [0:7)             sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#      for OY in [0:8)            sram_2MB          rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
#       for G in [0:2)            rf_2B             rf_128B           sram_2MB
# ---------------------------------------------------------------------------------
